# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import chi2_contingency

# %%
sales = pd.read_csv('Datasets/gameSales2016.csv', sep=',')

# %%
sales.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# ## Platform VS Genre

# %% [markdown]
# <font color='blue'><b><i>I expect there to be barely any correlation because every platform has all kinds of genres of games

# %%
contingencyTable = sales.groupby(['Platform','Genre']).size().unstack('Platform', fill_value=0)
contingencyTable
# Out:
# Platform      2600  3DO  3DS  DC   DS  GB  GBA   GC  GEN  GG  ...  SAT  SCD  \
# Genre                                                         ...
# Action          61    0  188   3  340   6  167  101    3   0  ...    3    0
# Adventure        2    1   38  11  238   5   38   20    2   0  ...   26    0
# Fighting         2    0   14  12   36   0   23   42    5   0  ...   31    0
# Misc             5    0   54   0  391   8  110   36    1   0  ...   15    2
# Platform         9    0   28   2   91  19  142   73    7   1  ...    5    1
# Puzzle          11    1   20   0  236  15   41   13    0   0  ...    5    0
# Racing           6    0   11   6   67   2   64   63    1   0  ...    8    1
# Role-Playing     0    0   88   4  200  21   73   27    3   0  ...   17    1
# Shooter         24    0    7   3   42   1   40   48    1   0  ...   22    0
# Simulation       1    1   31   1  284   5   18   12    0   0  ...    7    0
# ...

# %%
contingencyTable.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Genre'>

# %%
chi2_contingency(contingencyTable)
# Out:
# (5987.911286110601,
#  0.0,
#  330,
#  array([[2.68116289e+01, 6.04773584e-01, 1.04827421e+02, 1.04827421e+01,
#          4.33824251e+02, 1.97559371e+01, 1.65707962e+02, 1.12084704e+02,
#          5.44296225e+00, 2.01591195e-01, 6.43075911e+01, 1.97559371e+01,
#          2.41909434e+00, 1.96349824e+02, 2.01591195e-01, 2.41304660e+02,
#          4.35638572e+02, 2.68317880e+02, 7.92253395e+01, 2.43723754e+02,
#          8.70873961e+01, 3.48752767e+01, 1.20954717e+00, 4.81802955e+01,
#          4.03182389e-01, 1.20954717e+00, 2.66100377e+02, 2.96339056e+01,
#          2.54408088e+02, 1.66111144e+02, 4.97930251e+01],
#         [1.03666328e+01, 2.33833822e-01, 4.05311958e+01, 4.05311958e+00,
#          1.67736795e+02, 7.63857151e+00, 6.40704672e+01, 4.33372017e+01,
#          2.10450440e+00, 7.79446073e-02, 2.48643297e+01, 7.63857151e+00,
#          9.35335287e-01, 7.59180475e+01, 7.79446073e-02, 9.32996949e+01,
#          1.68438296e+02, 1.03744272e+02, 3.06322307e+01, 9.42350302e+01,
# ...

# %% [markdown]
# <font color='blue'><b><i>It seems like there is no correlation at all because the chi-squared is 0
