# %%
import pandas as pd

# %%
lifeExpectancyAtBirth = pd.read_csv('Datasets/lifeExpectancyAtBirth.csv', sep=',')

# %%
lifeExpectancyAtBirth.head()
# Out:
#       Location  Period                         Indicator        Dim1  \
# 0  Afghanistan    2019  Life expectancy at birth (years)  Both sexes
# 1  Afghanistan    2019  Life expectancy at birth (years)        Male
# 2  Afghanistan    2019  Life expectancy at birth (years)      Female
# 3  Afghanistan    2015  Life expectancy at birth (years)  Both sexes
# 4  Afghanistan    2015  Life expectancy at birth (years)        Male
#
#    First Tooltip
# 0          63.21
# 1          63.29
# 2          63.16
# 3          61.65
# 4          61.04

# %%
lifeExpectancyFiltered = lifeExpectancyAtBirth[(lifeExpectancyAtBirth.Period == 2019) & (lifeExpectancyAtBirth.Dim1 == "Both sexes")]

# %%
lifeExpectancyFiltered.head()
# Out:
#                Location  Period                         Indicator        Dim1  \
# 0           Afghanistan    2019  Life expectancy at birth (years)  Both sexes
# 12              Albania    2019  Life expectancy at birth (years)  Both sexes
# 24              Algeria    2019  Life expectancy at birth (years)  Both sexes
# 36               Angola    2019  Life expectancy at birth (years)  Both sexes
# 48  Antigua and Barbuda    2019  Life expectancy at birth (years)  Both sexes
#
#     First Tooltip
# 0           63.21
# 12          78.00
# 24          77.13
# 36          63.06
# 48          76.45

# %%
lifeExpectancyFiltered.describe()
# Out:
#        Period  First Tooltip
# count   183.0     183.000000
# mean   2019.0      72.540492
# std       0.0       7.129956
# min    2019.0      50.750000
# 25%    2019.0      66.550000
# 50%    2019.0      73.740000
# 75%    2019.0      77.730000
# max    2019.0      84.260000

# %%
lifeExpectancyFiltered['First Tooltip'].plot(kind='hist', bins=8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
lifeExpectancyFiltered['First Tooltip'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
pd.set_option('display.max_rows', None)

# %%
lifeExpectancyFiltered.sort_values(by="First Tooltip")
# Out:
#                                                Location  Period  \
# 1117                                            Lesotho    2019
# 373                            Central African Republic    2019
# 1801                                            Somalia    2019
# 661                                            Eswatini    2019
# 1333                                         Mozambique    2019
# 1045                                           Kiribati    2019
# 385                                                Chad    2019
# 829                                       Guinea-Bissau    2019
# 2185                                           Zimbabwe    2019
# 1741                                       Sierra Leone    2019
# 817                                              Guinea    2019
# 625                                   Equatorial Guinea    2019
# 252                                            Botswana    2019
# 541                    Democratic Republic of the Congo    2019
# ...
